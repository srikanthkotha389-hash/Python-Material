# %%
l=[1,2,3,4,5,'harsha',45.67,True]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 1

# %%
l[5]
# Out:
# 'harsha'

# %%
l[7]
# Out:
# True

# %%
len(l)
# Out:
# 8

# %%
l[0:5]
# Out:
# [1, 2, 3, 4, 5]

# %%
l[::-1]
# Out:
# [True, 45.67, 'harsha', 5, 4, 3, 2, 1]

# %%
l[0:100:2]
# Out:
# [1, 3, 5, 45.67]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'harsha', 45.67, True]

# %%
l[0:8:-1]
# Out:
# []

# %%
l[:3]
# Out:
# [1, 2, 3]

# %%
l+['srikanth']
# Out:
# [1, 2, 3, 4, 5, 'harsha', 45.67, True, 'srikanth']

# %%
l*2
# Out:
# [1, 2, 3, 4, 5, 'harsha', 45.67, True, 1, 2, 3, 4, 5, 'harsha', 45.67, True]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'harsha', 45.67, True]

# %%
60 in l
# Out:
# False

# %%
2 in l
# Out:
# True

# %%
max(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 max(l)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
l1=[2,3,4,5,6]

# %%
max(l1)
# Out:
# 6

# %%
min(l1)
# Out:
# 2

# %%
l2=['aimnext','datascience','Hyderabad']

# %%
min(l2)
# Out:
# 'Hyderabad'

# %%
max(l2)
# Out:
# 'data science'

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'harsha', 45.67, True]

# %%
l.append('steve')

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'harsha', 45.67, True, 'steve', 'steve', 'steve']

# %%
l.append([1,2,3,4,5])

# %%
l
# Out:
# [1,
#  2,
#  3,
#  4,
#  5,
#  'harsha',
#  45.67,
#  True,
#  'steve',
#  'steve',
#  'steve',
#  [1, 2, 3, 4, 5]]

# %%
l.pop(0)
# Out:
# 1

# %%
l
# Out:
# [2, 3, 4, 5, 'harsha', 45.67, True, 'steve', 'steve', 'steve', [1, 2, 3, 4, 5]]

# %%
l.pop()
# Out:
# [1, 2, 3, 4, 5]

# %%
l
# Out:
# [2, 3, 4, 5, 'harsha', 45.67, True, 'steve', 'steve', 'steve']

# %%
l.reverse()

# %%
l
# Out:
# ['steve', 'steve', 'steve', True, 45.67, 'harsha', 5, 4, 3, 2]

# %%
l[::-1]
# Out:
# [2, 3, 4, 5, 'harsha', 45.67, True, 'steve', 'steve', 'steve']

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'bool' and 'str'

# %%
l1
# Out:
# [2, 3, 4, 5, 6]

# %%
l1.sort()

# %%
l1
# Out:
# [2, 3, 4, 5, 6]

# %%
l3=[2,6,9,8,77,8,99]

# %%
l3.sort()

# %% [markdown]
# ###

# %%
l3
# Out:
# [2, 6, 8, 8, 9, 77, 99]

# %%
l3.sort(reverse=True)

# %%
l3
# Out:
# [99, 77, 9, 8, 8, 6, 2]

# %%
l1=[2,3,4]
l2=[6,7,8]
l3=[3,2,4]
l4=[l1,l2,l3]

# %%
l4
# Out:
# [[2, 3, 4], [6, 7, 8], [3, 2, 4]]

# %%
l4[1]
# Out:
# [6, 7, 8]

# %%
l4[2]
# Out:
# [3, 2, 4]

# %%
l4[0:2]
# Out:
# [[2, 3, 4], [6, 7, 8]]

# %%
l4[1][2]
# Out:
# 8

# %%
l4[2][2]
# Out:
# 4

# %%
l4[0][2]
# Out:
# 4

# %%
l
# Out:
# ['steve', 'steve', 'steve', True, 45.67, 'harsha', 5, 4, 3, 2]

# %%
l.count('steve')
# Out:
# 3

# %%
l5=[2,2,2,3,3,3,4,4,4]

# %%
l5.count(3)
# Out:
# 3

# %%
l
# Out:
# ['steve', 'steve', 'steve', True, 45.67, 'harsha', 5, 4, 3, 2]

# %%
l.extend('prathibha')

# %%
l
# Out:
# ['steve',
#  'steve',
#  'steve',
#  True,
#  45.67,
#  'harsha',
#  5,
#  4,
#  3,
#  2,
#  'p',
#  'r',
#  'a',
#  't',
#  'h',
#  'i',
#  'b',
#  'h',
#  'a']

# %%
l6=[1,2,3]

# %%
l6.extend([33,44,55])

# %%
l6
# Out:
# [1, 2, 3, 33, 44, 55]

# %%
l6.index(55)
# Out:
# 5

# %%
l=[1,2,3,4,5]

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 5

# %%
l.insert(1,[1,2,34])

# %%
l
# Out:
# [1, [1, 2, 34], 2, 3, 4, 5]

# %%
l.insert(5,['datascience'])

# %%
l
# Out:
# [1, [1, 2, 34], 2, 3, 4, ['datascience'], 5]

# %%
l.pop()
# Out:
# 5

# %%
l.pop(5)
# Out:
# ['datascience']

# %%
l
# Out:
# [1, [1, 2, 34], 2, 3, 4]

# %%
l.remove(3)

# %%
l
# Out:
# [1, [1, 2, 34], 2, 4]

# %%
l=[1,2,3,4,5]

# %%
l[1]
# Out:
# 2

# %%
l[1]='aimnext'

# %%
l
# Out:
# [1, 'aimnext', 3, 4, 5]

# %%
l[3]='datascience'

# %%
l
# Out:
# [1, 'aimnext', 3, 'datascience', 5]

# %%
s='aimnext'

# %%
s[2]
# Out:
# 'm'

# %%
s[2]='z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 s[2]='z'
#
# TypeError: 'str' object does not support item assignment

# %%
###tuple

# %%
t=()

# %%
type(t)
# Out:
# tuple

# %%
t=(4,5,6,7,'aimnext',55.45,'True')

# %%
len(t)
# Out:
# 7

# %%
t[4]
# Out:
# 'aimnext'

# %%
t[0:2:1]
# Out:
# (4, 5)

# %%
t[::-1]
# Out:
# ('True', 55.45, 'aimnext', 7, 6, 5, 4)

# %%
t
# Out:
# (4, 5, 6, 7, 'aimnext', 55.45, 'True')

# %%
t.count(3)
# Out:
# 0

# %%
t.count(5)
# Out:
# 1

# %%
t.index(6)
# Out:
# 2

# %%
t=list(t)

# %%
t
# Out:
# [4, 5, 6, 7, 'aimnext', 55.45, 'True']

# %%
type(t)
# Out:
# list

# %%
###dictionary

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={1}

# %%
type(d1)
# Out:
# set

# %%
d2={'key1':'value',234:'xyz','name':'aimnext','no':32324345}

# %%
type(d2)
# Out:
# dict

# %%
len(d2)
# Out:
# 4

# %%
d2.keys()
# Out:
# dict_keys(['key1', 234, 'name', 'no'])

# %%
d2.values()
# Out:
# dict_values(['value', 'xyz', 'aimnext', 32324345])

# %%
d2.items()
# Out:
# dict_items([('key1', 'value'), (234, 'xyz'), ('name', 'aimnext'), ('no', 32324345)])

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'aimnext', 'no': 32324345}

# %%
d2['name']
# Out:
# 'aimnext'

# %%
d2['key1']
# Out:
# 'value'

# %%
d3={'name':'aimnext','tech':['python','ml','dl','nlp','cv','big data','data analytics']}

# %%
len(d3)
# Out:
# 2

# %%
d3['tech']
# Out:
# ['python', 'ml', 'dl', 'nlp', 'cv', 'big data', 'data analytics']

# %%
d3.keys()
# Out:
# dict_keys(['name', 'tech'])

# %%
d3.values()
# Out:
# dict_values(['aimnext', ['python', 'ml', 'dl', 'nlp', 'cv', 'big data', 'data analytics']])

# %%
d3.items()
# Out:
# dict_items([('name', 'aimnext'), ('tech', ['python', 'ml', 'dl', 'nlp', 'cv', 'big data', 'data analytics'])])

# %%
'python'in d3['tech']
# Out:
# True

# %%
d4={'name':'aimnext','contac-info':565767,'name':'technologies'}

# %%
len(d4)
# Out:
# 2

# %%
d4['name1']='xyz'

# %%
d4
# Out:
# {'name': 'technologies', 'contac-info': 565767, 'name1': 'xyz'}

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'aimnext', 'no': 32324345}

# %%
d4['k2']=d2

# %%
d4
# Out:
# {'name': 'technologies',
#  'contac-info': 565767,
#  'name1': 'xyz',
#  'k2': {'key1': 'value', 234: 'xyz', 'name': 'aimnext', 'no': 32324345}}

# %%
d4['k2']
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'aimnext', 'no': 32324345}

# %%
d4['k2'][234]
# Out:
# 'xyz'

# %%
d4['contac-info']
# Out:
# 565767

# %%
d5={_:'sdsfs'}

# %%
d5[_]
# Out:
# 'sdsfs'

# %%
d6={(1,2,3,4):'fdfs'}

# %%
d6[(1,2,3,4)]
# Out:
# 'fdfs'

# %%
d7={[1,2,3,4]:'fdddd'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 d7={[1,2,3,4]:'fdddd'}
#
# TypeError: unhashable type: 'list'

# %%
d8={{3:4},'fsdf'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 d8={{3:4},'fsdf'}
#
# TypeError: unhashable type: 'dict'

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'aimnext', 'no': 32324345}

# %%
d2+d3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 d2+d3
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
#######sets operations

# %%
s={1,2,3,4,5}

# %%
type(s)
# Out:
# set

# %%
s1={3,4,4,4,5,6,6,7,7,8,8,9,9,9,0,0,0,0}

# %%
s1
# Out:
# {0, 3, 4, 5, 6, 7, 8, 9}

# %%
s3={'aimnext',324,34,12,645,12,5,'b','6'}

# %%
s3[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [69], in <cell line: 1>()
# ----> 1 s3[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s3[0]=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 s3[0]=2
#
# TypeError: 'set' object does not support item assignment

# %%
list(s3)
# Out:
# [34, 'b', 324, 5, 645, 12, '6', 'aimnext']

# %%
tuple(s3)
# Out:
# (34, 'b', 324, 5, 645, 12, '6', 'aimnext')

# %%
l=[2,3,4,4,5,6,7,88,88,99,88]

# %%
set(l)
# Out:
# {2, 3, 4, 5, 6, 7, 88, 99}

# %%
l=list(set(l))

# %%
l
# Out:
# [2, 3, 4, 5, 6, 7, 99, 88]

# %%
s2={123,456,789,901}

# %%
s2.add(876)

# %% [markdown]
# s2

# %%
s2
# Out:
# {123, 456, 789, 876, 901}

# %%
s2.add([1,2,3,4,5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [84], in <cell line: 1>()
# ----> 1 s2.add([1,2,3,4,5])
#
# TypeError: unhashable type: 'list'

# %%
s={(1,2,3,45),3,4,45,65,6}

# %%
s1={[1,2,3,4,5],3,4,5,6}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 s1={[1,2,3,4,5],3,4,5,6}
#
# TypeError: unhashable type: 'list'

# %%
s
# Out:
# {(1, 2, 3, 45), 3, 4, 45, 6, 65}

# %%
s.remove(4)

# %%
s
# Out:
# {(1, 2, 3, 45), 3, 45, 6, 65}

# %%
s.discard(34567688)

# %%
s
# Out:
# {(1, 2, 3, 45), 3, 45, 6, 65}

# %%
s.pop()
# Out:
# 65

# %%
s
# Out:
# {(1, 2, 3, 45), 3, 45, 6}
